# %% [markdown]
# # Agenda
# 1. [Intro](#Intro)
# 2. [Tortoise](#Tortoise)
# 3. [Own TTS](#own-small-tts)
# 4. [Homewor](#Homework)

# %% [markdown]
# # Intro

# %% [markdown]
# # Tortoise

# %% [markdown]
# https://arxiv.org/pdf/2305.07243

# %% [markdown]
# ## Ideas

# %% [markdown]
# 1. Scalable LLM for core generation
# 1. High quality diffusion for details rendering

# %% [markdown]
# ## General scheme

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## VQ-VAE

# %% [markdown]
# paper
#
# add general concept

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Speaker condition

# %% [markdown]
# ## Autoregressive Transformer

# %% [markdown]
# BPE
#
# check whisper lection
#
# * causal attention
# * transformer blocks
# * shift loss

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Diffusion decoder

# %% [markdown]
# * DDIM
# * pipeline configuration
# * latent input fine-tuning

# %% [markdown]
# ## CLVP

# %% [markdown]
# * CLIP
# * contrastive training, needed data

# %% [markdown]
# # Overview of TTS systems

# %% [markdown]
# ## VALL-E

# %% [markdown]
# ### Encodec

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### VALL-E

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## xTTS v2
#
# * pretrained speaker condition (two)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## CosyVoice 2
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Parler TTS
# ![image.png](attachment:image.png)

# %% [markdown]
# # Training LLM TTS

# %% [markdown]
# 1) gpt2 + one word dataset + pretrained vq
#
# 1.1) digits-only + gpt2
#
# 1.2) one-word + gpt2 kaggle
#
# 1.3) vctk + gpt2 kaggle
#
#
# 2) xtts fine-tune

# %% [markdown]
# * pretrained vq
# * bpe tokenazir
# * gpt2
# * diffusion (pre-trained?)

# %% [markdown]
# Inference of all blocks separately and full untrained pipeline

# %% [markdown]
# ## 1. Dataset

# %% [markdown]
# ## 2. VQ-VAE

# %% [markdown]
# ## 3. LLM

# %% [markdown]
# ## 4. Vocoder

# %% [markdown]
# # Homework

# %% [markdown]
# 1. Train llm component for TTS
# 1. Different setups
# 1. Implement different samplings for llm part (add references). Repetition penalty?
# 1. Metrics?
